# %%
from bs4 import BeautifulSoup

# %%
with open("stpb.html") as fp:
    soup = BeautifulSoup(fp)

# %%
headers = soup.find_all(['h1', 'h2'])

content = []

# Iterate through each header and its associated paragraphs
for header in headers:
    header_text = header.get_text(strip=True)
    paragraphs = []
    next_element = header.find_next_sibling()
    
    while next_element and next_element.name != header.name:
        if next_element.name == 'p':
            paragraphs.append(next_element.get_text(strip=True))
        next_element = next_element.find_next_sibling()

    # Create a dictionary for each topic with its paragraphs
    topic = {
        'title': header_text,
        'paragraphs': paragraphs
    }
    content.append(topic)

content = content[30:]

# %%
chapter_names = [topic.get("title")  for topic in content if topic.get('title')[0] == '[']
chapter_names.append("nonce")

# %%
chapter_names
# Out:
# ['[1] વિશ્લેષણ, વિષયના સ્વરૂપનું',
#  '[2] વિકારોથી વિમુક્તિની વાટ',
#  '[3] માહાત્મ્ય, બ્રહ્મચર્યનું',
#  '[1] વિષયથી, કઈ સમજણે છૂટાય ?',
#  '[2] દ્રષ્ટિ ઉખડે, ‘થ્રી વિઝને’',
#  '[3] દ્રઢ નિશ્ચય પહોંચાડે પાર',
#  '[4] વિષય વિચારો પજવે ત્યારે',
#  '[5] ન ચલાય, મનના કહ્યા પ્રમાણે',
#  '[6] ‘પોતે’ પોતાને વઢવો',
#  '[7] પસ્તાવા સહિતના પ્રતિક્રમણો',
#  '[8] સ્પર્શ સુખની ભ્રામક માન્યતા',
#  '[9] ‘ફાઈલ’ સામે કડકાઈ',
#  '[10] વિષયી વર્તન ? તો ડિસમીસ',
#  '[11] સેફસાઈડ સુધીની વાડ',
#  '[12] તિતિક્ષાનાં તપે કેળવો મન-દેહ',
#  '[13] ન હો અસાર, પુદ્ગલસાર',
#  '[14] બ્રહ્મચર્ય પમાડે બ્રહ્માંડનો આનંદ',
#  '[15] ‘વિષય’ સામે વિજ્ઞાનની જાગૃતિ',
#  '[16] લપસનારાંઓને ઉઠાડી દોડાવે',
#  '[17] અંતિમ અવતારમાંય બ્રહ્મચર્ય તો આવશ્યક',
#  '[18] દાદા આપે પુષ્ટિ, આપ્તપુત્રીઓને',
#  'nonce']

# %%
import json
topics = list()
chapter_count = -1



for val in content:
    topic = dict()
    
    if val.get("title") == chapter_names[chapter_count+1]:
        chapter_count+=1
        continue

    if val.get("title")[:3] !=  "ખંડ" and val.get("title") != chapter_names[chapter_count+1]:
        topic["chapter_name"] = chapter_names[chapter_count]
        topic["topic_name"] = val.get("title")
        topic["paragraphs"] = val.get("paragraphs")
        topics.append(topic)


with open('stpb.json', 'w', encoding='utf8') as fout:
    json.dump(topics , fout, ensure_ascii=False)

# %%
topics
# Out:
# [{'chapter_name': '[1] વિશ્લેષણ, વિષયના સ્વરૂપનું',
#   'topic_name': 'કીચડમાં ઠંડકની મઝા',
#   'paragraphs': ['આ પાંચ ઇન્દ્રિયના કીચડમાં મનુષ્ય થઈને કેમ પડ્યા છે એ જ અજાયબી છે ! \nભયંકર કીચડ છે આ તો ! પણ એ નહીં સમજવાથી, બેભાનપણાથી જગત ચાલ્યા કરે છે. એક\n સહેજ જો વિચારે તોય કીચડ સમજાય. પણ આ લોકો વિચારતા જ નથી ને ?! નર્યો કીચડ\n છે. તો મનુષ્યો કેમ આવા કીચડમાં પડ્યા છે ? ત્યારે કહે, ‘બીજી જગ્યાએ \nચોખ્ખું મળતું નથી. એટલે આવા કીચડમાં સૂઈ ગયો છે.’',
#    'પ્રશ્નકર્તા :એટલે કીચડ માટેની અજ્ઞાનતા જ છે ને ?',
#    'દાદાશ્રી :હા, એની અજ્ઞાનતા છે. એટલે જ કીચડમાં પડ્યો છે. \nપાછું આને જો સમજવા પ્રયત્ન કરે તો સમજાય એવું છે, પણ પોતે સમજવા પ્રયત્ન જ\n નથી કરતો ને !',
#    'કોઈ કહે કે જાનવરોને આ વિષયો પ્રિય છે ? તો હું કહું કે ના, જાનવરોને આ\n વિષયો બિલકુલ પસંદ નથી. પણ છતાંય એમને ‘નેચરલ’ ઉશ્કેરાટ થાય છે. બાકી આ \nવિષયને કોઈ પસંદ જ ના કરે, સાચો પુરુષ',
# ...
